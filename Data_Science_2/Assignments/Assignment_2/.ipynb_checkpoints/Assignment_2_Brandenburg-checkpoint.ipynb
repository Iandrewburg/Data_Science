# %% [markdown]
# # <center> **DATA SCIENCE 2: ASSIGNMENT 2**
#
# ### <center> *Ian Brandenburg (2304791)* <center> [GitHub Repo](https://github.com/Iandrewburg/Data_Science/tree/main/Data_Science_2/Assignments/Assignment_2)
# ---
#
#
# Take the alternative version of the famous “MNIST dataset”, which consists of images of Zalando’s articles. Your task is to correctly classify the images into one of the ten categories, such as dress or shirt. The images are in exactly the same format as we saw for the handwritten digits: 28x28 pixel grayscale images. The task is to build deep neural network models to predict the items. You can use either sklearn or keras; to get the data, go to the corresponding Kaggle page or use the fashion_mnist.load_data() function from the keras.datasets module. Make sure you split the training set into two sets: one for training your models on and one for validation and model selection. You can work with a relatively small train set if you have computational problems.

# %% [markdown]
# ### 1. What would be an appropriate metric to evaluate your models? Why?
# ---

# %% [markdown]
# An appropriate metric to evalute the models train on the Fashion MNIST data set would be the accuracy metric, since the dataset is a multi-class classification problem with balanced classes. The accuracy metric calculates the number of correctly predicted observations to the total number of observations. This provides a very straightforward assessment of the models' performance across the 10 different categories.

# %% [markdown]
# ### 2. Get the data and show some example images from the data.
# ---

# %%
import numpy as np
from keras.datasets import fashion_mnist
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt

def plot_model_history(model_histories, labels):
    """Plot the training and validation accuracy and loss for multiple models."""
    if not model_histories or not labels or len(model_histories) != len(labels):
        print("The model histories and labels must be provided and match in length.")
        return

    plt.figure(figsize=(14, 5))

    # Plot training & validation accuracy
    plt.subplot(1, 2, 1)
    for model_history, label in zip(model_histories, labels):
        epochs = range(1, len(model_history.history['accuracy']) + 1)
        plt.plot(epochs, model_history.history['accuracy'], label=f'Training Acc {label}')
        plt.plot(epochs, model_history.history['val_accuracy'], label=f'Validation Acc {label}', linestyle="--")
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training & validation loss
    plt.subplot(1, 2, 2)
    for model_history, label in zip(model_histories, labels):
        epochs = range(1, len(model_history.history['loss']) + 1)
        plt.plot(epochs, model_history.history['loss'], label=f'Training Loss {label}')
        plt.plot(epochs, model_history.history['val_loss'], label=f'Validation Loss {label}', linestyle="--")
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# loading the dataset
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# converting labels to one-hot encoding
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# splitting the training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=20240405)

# checking the shape of the datasets
print("Training set shape:", train_images.shape)
print("Validation set shape:", val_images.shape)
print("Test set shape:", test_images.shape)
# Out:
# Training set shape: (48000, 28, 28)
# Validation set shape: (12000, 28, 28)
# Test set shape: (10000, 28, 28)

# %%
print("Y Test set shape:", test_labels.shape)
# Out:
# Y Test set shape: (10000, 10)

# %%
def show_images(images, labels, nrows=1, ncols=5, class_names=None):
    """Display a grid of images and their labels."""
    plt.figure(figsize=(10, 2 * nrows))
    for i in range(nrows * ncols):
        plt.subplot(nrows, ncols, i + 1)
        plt.imshow(images[i], cmap='gray')
        plt.colorbar()
        if class_names is not None:
            plt.title(class_names[np.argmax(labels[i])])
        else:
            plt.title(np.argmax(labels[i]))
        plt.axis('off')
    plt.show()

class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# Assuming train_images, val_images, test_images are your datasets
# And train_labels, val_labels, test_labels are the corresponding labels

# Show some training images
print("Training Images:")
show_images(train_images, train_labels, nrows=2, ncols=5, class_names=class_names)

# Show some validation images
print("Validation Images:")
show_images(val_images, val_labels, nrows=2, ncols=5, class_names=class_names)

# Show some testing images
print("Test Images:")
show_images(test_images, test_labels, nrows=2, ncols=5, class_names=class_names)
# Out:
# Training Images:
# Validation Images:
# Test Images:

# %% [markdown]
# ### 3. Train a simple fully connected single hidden layer network to predict the items.
#
# - Remember to normalize the data similar to what we did in class. Make sure that you use enough epochs so that the validation error begins to level off - provide a plot of the training history.

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Rescaling
from keras.callbacks import EarlyStopping

model = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),  # This layer scales input pixels to 0-1
    Flatten(),  # Convert 2D images to 1D vectors
    Dense(256, activation='relu'),  # Hidden layer with 256 units and ReLU activation
    Dense(10, activation='softmax')  # Output layer with 10 units (one for each class) and softmax activation
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

print(model.summary())

history = model.fit(train_images, 
                    train_labels, 
                    epochs=25, 
                    validation_data=(val_images, val_labels), 
                    callbacks=[EarlyStopping(monitor='val_accuracy', 
                                             patience=5)])
# Out:
# C:\Users\iandr\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 203,530 (795.04 KB)
#  Trainable params: 203,530 (795.04 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.7781 - loss: 0.6327 - val_accuracy: 0.8633 - val_loss: 0.3904
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8633 - loss: 0.3778 - val_accuracy: 0.8593 - val_loss: 0.3797
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8732 - loss: 0.3420 - val_accuracy: 0.8715 - val_loss: 0.3556
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8882 - loss: 0.3060 - val_accuracy: 0.8683 - val_loss: 0.3589
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8913 - loss: 0.2916 - val_accuracy: 0.8777 - val_loss: 0.3324
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8994 - loss: 0.2706 - val_accuracy: 0.8881 - val_loss: 0.3105
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9009 - loss: 0.2616 - val_accuracy: 0.8779 - val_loss: 0.3233
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9066 - loss: 0.2514 - val_accuracy: 0.8907 - val_loss: 0.3045
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9117 - loss: 0.2380 - val_accuracy: 0.8770 - val_loss: 0.3458
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9147 - loss: 0.2278 - val_accuracy: 0.8851 - val_loss: 0.3255
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9207 - loss: 0.2143 - val_accuracy: 0.8871 - val_loss: 0.3189
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9226 - loss: 0.2103 - val_accuracy: 0.8926 - val_loss: 0.3037
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9229 - loss: 0.2013 - val_accuracy: 0.8788 - val_loss: 0.3517
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9241 - loss: 0.2025 - val_accuracy: 0.8942 - val_loss: 0.3142
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9280 - loss: 0.1893 - val_accuracy: 0.8938 - val_loss: 0.3142
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9320 - loss: 0.1820 - val_accuracy: 0.8903 - val_loss: 0.3227
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9351 - loss: 0.1750 - val_accuracy: 0.8905 - val_loss: 0.3266
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9359 - loss: 0.1713 - val_accuracy: 0.8840 - val_loss: 0.3642
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9381 - loss: 0.1666 - val_accuracy: 0.8847 - val_loss: 0.3459

# %% [markdown]
# The model above flattens the data, since we are looking at developing a fully connected hidden layer, subsequently converting the 2D images to 1D vectors. A hidden layer with 128 units was created, using ReLU activation. Finally, the moodel sets the output layer to 10 units (one for each category), and uses softmax activation on the output. 25 epochs were used to ensure the accuracy metric would level off. This was tested by using the EarlyStopping function with a patience of 5. It stops at 19 epochs with a validation accuracy of 0.8847. There is still room for improvement, so we will try various other models to attempt to improve the accuracy and decrease the loss without overfitting.

# %%
plot_model_history([history], ['Model'])

# %% [markdown]
# Here, both the loss and accuracy metrics for the validation set level off before the training loss and accuracy. The training loss seems to still be decreasing while the accuracy increasing, at the time that the EarlyStopping function stops the epochs from running further. Visually, it seems like the training set does not predict the validation model very well; however, they are not very far off in their accuracy and loss metrics, so this model my not be bad.

# %% [markdown]
# ### 4. Experiment with different network architectures and settings (number of hidden layers, number of nodes, regularization, etc.).
#
# - Train at least 3 models. Explain what you have tried and how it worked.

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# Define model
model1 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),  # This layer scales input pixels to 0-1
    Flatten(),
    Dense(512, activation='relu'),  # Increased number of nodes
    Dense(10, activation='softmax')
])

model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history1 = model1.fit(train_images, train_labels, epochs=25, validation_data=(val_images, val_labels), callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7815 - loss: 0.6180 - val_accuracy: 0.8461 - val_loss: 0.4196
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8601 - loss: 0.3778 - val_accuracy: 0.8647 - val_loss: 0.3678
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8801 - loss: 0.3340 - val_accuracy: 0.8515 - val_loss: 0.3943
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8870 - loss: 0.3025 - val_accuracy: 0.8835 - val_loss: 0.3245
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8948 - loss: 0.2854 - val_accuracy: 0.8763 - val_loss: 0.3385
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9008 - loss: 0.2664 - val_accuracy: 0.8654 - val_loss: 0.3790
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9038 - loss: 0.2526 - val_accuracy: 0.8774 - val_loss: 0.3479
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9092 - loss: 0.2414 - val_accuracy: 0.8842 - val_loss: 0.3283
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9136 - loss: 0.2333 - val_accuracy: 0.8898 - val_loss: 0.3067
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9202 - loss: 0.2172 - val_accuracy: 0.8797 - val_loss: 0.3417
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9198 - loss: 0.2164 - val_accuracy: 0.8922 - val_loss: 0.3152
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9231 - loss: 0.2074 - val_accuracy: 0.8931 - val_loss: 0.3128
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9253 - loss: 0.1932 - val_accuracy: 0.8857 - val_loss: 0.3329
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9276 - loss: 0.1931 - val_accuracy: 0.8902 - val_loss: 0.3242
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9305 - loss: 0.1839 - val_accuracy: 0.8916 - val_loss: 0.3246
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9338 - loss: 0.1744 - val_accuracy: 0.8850 - val_loss: 0.3474
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9382 - loss: 0.1693 - val_accuracy: 0.8930 - val_loss: 0.3312

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# Define model
model2 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),  # This layer scales input pixels to 0-1
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),  # Add dropout
    Dense(10, activation='softmax')
])

model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history2 = model2.fit(train_images, train_labels, epochs=25, validation_data=(val_images, val_labels), callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7470 - loss: 0.7203 - val_accuracy: 0.8420 - val_loss: 0.4357
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8352 - loss: 0.4527 - val_accuracy: 0.8609 - val_loss: 0.3765
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8459 - loss: 0.4172 - val_accuracy: 0.8549 - val_loss: 0.3880
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8557 - loss: 0.3918 - val_accuracy: 0.8620 - val_loss: 0.3733
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8584 - loss: 0.3824 - val_accuracy: 0.8636 - val_loss: 0.3542
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8659 - loss: 0.3641 - val_accuracy: 0.8748 - val_loss: 0.3447
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8669 - loss: 0.3591 - val_accuracy: 0.8716 - val_loss: 0.3447
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8701 - loss: 0.3502 - val_accuracy: 0.8787 - val_loss: 0.3250
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8759 - loss: 0.3364 - val_accuracy: 0.8828 - val_loss: 0.3233
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8766 - loss: 0.3339 - val_accuracy: 0.8802 - val_loss: 0.3286
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8797 - loss: 0.3279 - val_accuracy: 0.8852 - val_loss: 0.3187
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8837 - loss: 0.3129 - val_accuracy: 0.8823 - val_loss: 0.3238
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8833 - loss: 0.3182 - val_accuracy: 0.8832 - val_loss: 0.3221
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8815 - loss: 0.3148 - val_accuracy: 0.8853 - val_loss: 0.3125
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8853 - loss: 0.3052 - val_accuracy: 0.8883 - val_loss: 0.3154
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8890 - loss: 0.2968 - val_accuracy: 0.8887 - val_loss: 0.3104
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8907 - loss: 0.2939 - val_accuracy: 0.8863 - val_loss: 0.3220
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8919 - loss: 0.2961 - val_accuracy: 0.8814 - val_loss: 0.3279
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8869 - loss: 0.3016 - val_accuracy: 0.8844 - val_loss: 0.3268
# Epoch 20/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8922 - loss: 0.2863 - val_accuracy: 0.8836 - val_loss: 0.3250
# Epoch 21/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8948 - loss: 0.2815 - val_accuracy: 0.8886 - val_loss: 0.3102

# %%
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping

# Define model
model3 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),  # This layer scales input pixels to 0-1
    Flatten(),
    Dense(256, activation='relu'),
    Dense(256, activation='relu'),  # Additional hidden layer
    Dense(10, activation='softmax')
])

model3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history3 = model3.fit(train_images, train_labels, epochs=25, validation_data=(val_images, val_labels), callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7778 - loss: 0.6194 - val_accuracy: 0.8622 - val_loss: 0.3800
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8623 - loss: 0.3776 - val_accuracy: 0.8643 - val_loss: 0.3722
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8778 - loss: 0.3346 - val_accuracy: 0.8635 - val_loss: 0.3679
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8889 - loss: 0.3053 - val_accuracy: 0.8818 - val_loss: 0.3203
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8938 - loss: 0.2864 - val_accuracy: 0.8788 - val_loss: 0.3313
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8971 - loss: 0.2764 - val_accuracy: 0.8813 - val_loss: 0.3240
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9043 - loss: 0.2546 - val_accuracy: 0.8840 - val_loss: 0.3219
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9066 - loss: 0.2472 - val_accuracy: 0.8863 - val_loss: 0.3179
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9117 - loss: 0.2337 - val_accuracy: 0.8909 - val_loss: 0.3208
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9154 - loss: 0.2243 - val_accuracy: 0.8851 - val_loss: 0.3233
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9194 - loss: 0.2147 - val_accuracy: 0.8885 - val_loss: 0.3199
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9241 - loss: 0.1956 - val_accuracy: 0.8901 - val_loss: 0.3288
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9274 - loss: 0.1954 - val_accuracy: 0.8887 - val_loss: 0.3272
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9288 - loss: 0.1844 - val_accuracy: 0.8805 - val_loss: 0.4133

# %%
# Define model
model4 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),
    Flatten(),
    Dense(512, activation='relu'),  # Increased number of nodes
    Dropout(0.5),  # Add dropout
    Dense(512, activation='relu'),  # Increased number of nodes
    Dropout(0.5),  # Add dropout
    Dense(10, activation='softmax')
])

model4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train model
history4 = model4.fit(train_images, train_labels, epochs=25, validation_data=(val_images, val_labels), callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.7071 - loss: 0.7970 - val_accuracy: 0.8212 - val_loss: 0.4906
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8184 - loss: 0.5056 - val_accuracy: 0.8540 - val_loss: 0.4022
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8348 - loss: 0.4571 - val_accuracy: 0.8528 - val_loss: 0.3944
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8391 - loss: 0.4452 - val_accuracy: 0.8619 - val_loss: 0.3661
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8488 - loss: 0.4252 - val_accuracy: 0.8672 - val_loss: 0.3666
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8514 - loss: 0.4143 - val_accuracy: 0.8641 - val_loss: 0.3662
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8516 - loss: 0.4030 - val_accuracy: 0.8669 - val_loss: 0.3712
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8542 - loss: 0.4063 - val_accuracy: 0.8689 - val_loss: 0.3532
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8546 - loss: 0.3948 - val_accuracy: 0.8619 - val_loss: 0.3645
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8598 - loss: 0.3891 - val_accuracy: 0.8676 - val_loss: 0.3604
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8611 - loss: 0.3884 - val_accuracy: 0.8715 - val_loss: 0.3494
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8628 - loss: 0.3820 - val_accuracy: 0.8692 - val_loss: 0.3564
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8632 - loss: 0.3740 - val_accuracy: 0.8698 - val_loss: 0.3510
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8678 - loss: 0.3750 - val_accuracy: 0.8673 - val_loss: 0.3688
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8669 - loss: 0.3703 - val_accuracy: 0.8683 - val_loss: 0.3590
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8722 - loss: 0.3554 - val_accuracy: 0.8767 - val_loss: 0.3374
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.8712 - loss: 0.3601 - val_accuracy: 0.8735 - val_loss: 0.3446
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8695 - loss: 0.3612 - val_accuracy: 0.8662 - val_loss: 0.3485
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8717 - loss: 0.3581 - val_accuracy: 0.8688 - val_loss: 0.3466
# Epoch 20/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8707 - loss: 0.3605 - val_accuracy: 0.8817 - val_loss: 0.3367
# Epoch 21/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8733 - loss: 0.3526 - val_accuracy: 0.8646 - val_loss: 0.3529
# Epoch 22/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8732 - loss: 0.3484 - val_accuracy: 0.8759 - val_loss: 0.3378
# Epoch 23/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8716 - loss: 0.3539 - val_accuracy: 0.8721 - val_loss: 0.3494
# Epoch 24/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8781 - loss: 0.3449 - val_accuracy: 0.8775 - val_loss: 0.3468
# Epoch 25/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8767 - loss: 0.3432 - val_accuracy: 0.8753 - val_loss: 0.3479

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

model5 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),  # This layer scales input pixels to 0-1
    Flatten(),
    Dense(256, activation='relu'),  # Reduced number of nodes
    BatchNormalization(),  # Add batch normalization
    Dropout(0.3),  # Reduced dropout rate
    Dense(256, activation='relu'),  # Reduced number of nodes
    BatchNormalization(),  # Add batch normalization
    Dropout(0.3),  # Reduced dropout rate
    Dense(10, activation='softmax')
])

model5.compile(optimizer=Adam(learning_rate=0.001),  # Adjust learning rate
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Assuming you have defined train_images, train_labels, val_images, val_labels
history5 = model5.fit(train_images, train_labels, epochs=25, validation_data=(val_images, val_labels),
                      callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.7442 - loss: 0.7510 - val_accuracy: 0.8407 - val_loss: 0.4303
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8278 - loss: 0.4798 - val_accuracy: 0.8517 - val_loss: 0.4059
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8362 - loss: 0.4467 - val_accuracy: 0.8599 - val_loss: 0.3779
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8458 - loss: 0.4292 - val_accuracy: 0.8616 - val_loss: 0.3813
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8450 - loss: 0.4245 - val_accuracy: 0.8558 - val_loss: 0.3812
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8517 - loss: 0.4067 - val_accuracy: 0.8597 - val_loss: 0.3759
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8567 - loss: 0.3868 - val_accuracy: 0.8700 - val_loss: 0.3437
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8629 - loss: 0.3777 - val_accuracy: 0.8679 - val_loss: 0.3538
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8617 - loss: 0.3856 - val_accuracy: 0.8753 - val_loss: 0.3302
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8644 - loss: 0.3650 - val_accuracy: 0.8699 - val_loss: 0.3463
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8686 - loss: 0.3622 - val_accuracy: 0.8663 - val_loss: 0.3482
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8722 - loss: 0.3502 - val_accuracy: 0.8745 - val_loss: 0.3292
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8749 - loss: 0.3442 - val_accuracy: 0.8738 - val_loss: 0.3451
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8735 - loss: 0.3462 - val_accuracy: 0.8805 - val_loss: 0.3237
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8741 - loss: 0.3384 - val_accuracy: 0.8755 - val_loss: 0.3331
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8792 - loss: 0.3310 - val_accuracy: 0.8788 - val_loss: 0.3222
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8782 - loss: 0.3323 - val_accuracy: 0.8773 - val_loss: 0.3268
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8779 - loss: 0.3335 - val_accuracy: 0.8793 - val_loss: 0.3229
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8811 - loss: 0.3260 - val_accuracy: 0.8808 - val_loss: 0.3258
# Epoch 20/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8808 - loss: 0.3269 - val_accuracy: 0.8810 - val_loss: 0.3162
# Epoch 21/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8812 - loss: 0.3226 - val_accuracy: 0.8851 - val_loss: 0.3067
# Epoch 22/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8832 - loss: 0.3120 - val_accuracy: 0.8829 - val_loss: 0.3117
# Epoch 23/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8846 - loss: 0.3169 - val_accuracy: 0.8815 - val_loss: 0.3186
# Epoch 24/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8867 - loss: 0.3067 - val_accuracy: 0.8821 - val_loss: 0.3215
# Epoch 25/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8862 - loss: 0.3051 - val_accuracy: 0.8805 - val_loss: 0.3215

# %%
plot_model_history([history, history1, history2, history3, history4, history5], ['Model', 'Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5'])

# %%
plot_model_history([history5], ['Model 5'])

# %% [markdown]
# ### 5. Try to improve the accuracy of your model by using convolution.
# - Train at least two different models (you can vary the number of convolutional and pooling layers or whether you include a fully connected layer before the output, etc.).

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Rescaling

model6 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),  # Scale input pixels to 0-1
    Conv2D(32, (3, 3), activation='relu'),  # Convolutional layer
    MaxPooling2D((2, 2)),  # Pooling layer
    Flatten(),  # Convert 3D feature maps to 1D feature vectors
    Dense(256, activation='relu'),  # Hidden layer
    Dense(10, activation='softmax')  # Output layer
])

model6.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

print(model6.summary())

# Assuming train_images, train_labels, val_images, val_labels are correctly shaped for a CNN
history6 = model6.fit(train_images, train_labels, epochs=25,
                      validation_data=(val_images, val_labels),
                      callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_6 (Rescaling)         │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_6 (Flatten)             │ (None, 5408)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 256)            │     1,384,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,387,594 (5.29 MB)
#  Trainable params: 1,387,594 (5.29 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 19s 12ms/step - accuracy: 0.8098 - loss: 0.5361 - val_accuracy: 0.8873 - val_loss: 0.3036
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9013 - loss: 0.2748 - val_accuracy: 0.8920 - val_loss: 0.2851
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9183 - loss: 0.2216 - val_accuracy: 0.9082 - val_loss: 0.2517
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9353 - loss: 0.1788 - val_accuracy: 0.9120 - val_loss: 0.2378
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9464 - loss: 0.1513 - val_accuracy: 0.9145 - val_loss: 0.2460
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9545 - loss: 0.1234 - val_accuracy: 0.9143 - val_loss: 0.2615
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9649 - loss: 0.0971 - val_accuracy: 0.9090 - val_loss: 0.2805
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9698 - loss: 0.0826 - val_accuracy: 0.9117 - val_loss: 0.3000
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9778 - loss: 0.0632 - val_accuracy: 0.9128 - val_loss: 0.3062
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9805 - loss: 0.0574 - val_accuracy: 0.9167 - val_loss: 0.3227
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9845 - loss: 0.0462 - val_accuracy: 0.9131 - val_loss: 0.3746
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9882 - loss: 0.0347 - val_accuracy: 0.9147 - val_loss: 0.3754
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9907 - loss: 0.0278 - val_accuracy: 0.9107 - val_loss: 0.4149
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9927 - loss: 0.0244 - val_accuracy: 0.9187 - val_loss: 0.4140
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.9926 - loss: 0.0220 - val_accuracy: 0.9133 - val_loss: 0.4415
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9937 - loss: 0.0185 - val_accuracy: 0.9118 - val_loss: 0.4721
# Epoch 17/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9937 - loss: 0.0189 - val_accuracy: 0.9153 - val_loss: 0.4910
# Epoch 18/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9945 - loss: 0.0166 - val_accuracy: 0.9118 - val_loss: 0.5214
# Epoch 19/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9948 - loss: 0.0158 - val_accuracy: 0.9104 - val_loss: 0.5485

# %%
from tensorflow.keras.layers import Dropout

model7 = Sequential([
    Rescaling(1./255, input_shape=(28, 28, 1)),
    Conv2D(64, (3, 3), activation='relu'),  # Increase the number of filters
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),  # Additional convolutional layer
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(256, activation='relu'),  # Smaller dense layer before output
    Dropout(0.5),  # Include dropout
    Dense(10, activation='softmax')
])

model7.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

print(model7.summary())

history7 = model7.fit(train_images, train_labels, epochs=25,
                      validation_data=(val_images, val_labels),
                      callbacks=[EarlyStopping(monitor='val_accuracy', patience=5)])
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling_7 (Rescaling)         │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 26, 26, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 13, 13, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 11, 11, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_7 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 256)            │       409,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 449,994 (1.72 MB)
#  Trainable params: 449,994 (1.72 MB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 11ms/step - accuracy: 0.7409 - loss: 0.7214 - val_accuracy: 0.8712 - val_loss: 0.3505
# Epoch 2/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8692 - loss: 0.3628 - val_accuracy: 0.8857 - val_loss: 0.3023
# Epoch 3/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 18s 12ms/step - accuracy: 0.8883 - loss: 0.3066 - val_accuracy: 0.9002 - val_loss: 0.2669
# Epoch 4/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.8996 - loss: 0.2737 - val_accuracy: 0.9048 - val_loss: 0.2567
# Epoch 5/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9090 - loss: 0.2511 - val_accuracy: 0.9062 - val_loss: 0.2527
# Epoch 6/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9194 - loss: 0.2213 - val_accuracy: 0.9007 - val_loss: 0.2585
# Epoch 7/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9196 - loss: 0.2147 - val_accuracy: 0.9134 - val_loss: 0.2368
# Epoch 8/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9237 - loss: 0.1945 - val_accuracy: 0.9067 - val_loss: 0.2616
# Epoch 9/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9290 - loss: 0.1871 - val_accuracy: 0.9090 - val_loss: 0.2462
# Epoch 10/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9347 - loss: 0.1706 - val_accuracy: 0.9148 - val_loss: 0.2498
# Epoch 11/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9390 - loss: 0.1610 - val_accuracy: 0.9169 - val_loss: 0.2509
# Epoch 12/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9452 - loss: 0.1465 - val_accuracy: 0.9147 - val_loss: 0.2571
# Epoch 13/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 17s 11ms/step - accuracy: 0.9485 - loss: 0.1390 - val_accuracy: 0.9136 - val_loss: 0.2662
# Epoch 14/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9495 - loss: 0.1316 - val_accuracy: 0.9107 - val_loss: 0.2839
# Epoch 15/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9526 - loss: 0.1240 - val_accuracy: 0.9152 - val_loss: 0.2664
# Epoch 16/25
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 16s 11ms/step - accuracy: 0.9563 - loss: 0.1169 - val_accuracy: 0.9153 - val_loss: 0.2791

# %%
plot_model_history([history6, history7], ['Model 6', 'Model 7'])

# %%
plot_model_history([history, history1, history2, history3, history4, history5, history6, history7], ['Model', 'Model 1', 'Model 2', 'Model 3', 'Model 4', 'Model 5', 'Model 6', 'Model 7'])

# %% [markdown]
# #### 6. Try to use a pre-trained network to improve accuracy.
#
# Note to self, I think we used this in class? Not 100% sure, but this might be referncing the one we used in the class.

# %%
import tensorflow as tf

def pad_images(images):
    # Ensure images have a channel dimension, expected shape: [num_images, height, width, channels]
    if images.ndim == 3:
        images = images[..., tf.newaxis]

    # Define padding to add 2 pixels on top, bottom, left, and right, and no padding on the batch and channels
    padding = [[0, 0], [2, 2], [2, 2], [0, 0]]
    
    # Apply constant padding
    images_padded = tf.pad(images, paddings=padding, mode='CONSTANT', constant_values=0)
    return images_padded

train_images_padded = pad_images(train_images)
val_images_padded = pad_images(val_images)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model

# Load MobileNetV2 without the top layer to use as a base model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3), alpha=1.0)

# Freeze the base model layers
base_model.trainable = False

model8 = Sequential([
    base_model,
    GlobalAveragePooling2D(),  # Reduces each feature map to a single value
    BatchNormalization(),
    Dense(1024, activation='relu'),
    Dropout(0.5),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

# Compile the enhanced model
model8.compile(optimizer='adam',
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])
# Out:
# C:\Users\iandr\AppData\Local\Temp\ipykernel_61424\2704174607.py:7: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(32, 32, 3), alpha=1.0)

# %%
def convert_to_rgb(images):
    # Images are expected to be in [num_images, 32, 32, 1]
    # Convert them to RGB by repeating the single channel three times
    images_rgb = tf.repeat(images, 3, axis=-1)
    return images_rgb

train_images_rgb = convert_to_rgb(train_images_padded)
val_images_rgb = convert_to_rgb(val_images_padded)

# %%
# Fit the model
history8 = model8.fit(
    train_images_rgb, train_labels,
    epochs=10,
    validation_data=(val_images_rgb, val_labels),
    callbacks=[EarlyStopping(monitor='val_accuracy', patience=3)])
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 61s 36ms/step - accuracy: 0.4465 - loss: 1.4921 - val_accuracy: 0.5271 - val_loss: 1.2533
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 52s 35ms/step - accuracy: 0.5100 - loss: 1.3085 - val_accuracy: 0.5397 - val_loss: 1.2411
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 52s 35ms/step - accuracy: 0.5209 - loss: 1.2848 - val_accuracy: 0.5437 - val_loss: 1.2276
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 475s 317ms/step - accuracy: 0.5276 - loss: 1.2676 - val_accuracy: 0.5523 - val_loss: 1.2071
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 58s 38ms/step - accuracy: 0.5374 - loss: 1.2388 - val_accuracy: 0.5466 - val_loss: 1.2113
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 56s 37ms/step - accuracy: 0.5367 - loss: 1.2379 - val_accuracy: 0.5518 - val_loss: 1.2128
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 56s 37ms/step - accuracy: 0.5372 - loss: 1.2363 - val_accuracy: 0.5501 - val_loss: 1.2023

# %% [markdown]
# #### 2 points) Select a final model and evaluate it on the test set. How does the test error compare to the validation error?

# %%
import pandas as pd


# Assuming 'models' contains all your model instances
models = [model, model1, model2, model3, model4, model5, model6, model7]

# Initialize an empty list to store results
results = []

# Loop through each model and evaluate it
for i, model in enumerate(models):
    test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=2)
    # Append results to the list
    results.append({'Model': f'Model{i}', 'Loss': test_loss, 'Accuracy': test_accuracy})

# Convert the list of results into a DataFrame
results_df = pd.DataFrame(results)

results_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 12
#      10 # Loop through each model and evaluate it
#      11 for i, model in enumerate(models_images):
# ---> 12     test_loss, test_accuracy = model.evaluate(test_images, test_labels, verbose=2)
#      13     # Append results to the list
#      14     results.append({'Model': f'Model{i}', 'Loss': test_loss, 'Accuracy': test_accuracy})
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:123, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#     121     # To get the full stack trace, call:
#     122     # `keras.config.disable_traceback_filtering()`
# --> 123     raise e.with_traceback(filtered_tb) from None
#     124 finally:
#     125     del filtered_tb
#
# ValueError: Exception encountered when calling Sequential.call().
#
# Cannot take the length of shape with unknown rank.
#
# Arguments received by Sequential.call():
#   • inputs=tf.Tensor(shape=<unknown>, dtype=uint8)
#   • training=False
#   • mask=None

# %%
from tensorflow.keras.losses import MeanSquaredError
import numpy as np

# Assuming model5 is compiled and ready for predictions
# Predicting on the test set
test_predictions = model7.predict(test_images)

# Assuming test_labels are in the correct shape for regression (or adjusted for classification)
mse = MeanSquaredError()
test_mse = mse(test_labels, test_predictions).numpy()

# Assuming you have the validation MSE stored. Let's say it's 0.02 for example.
validation_mse = 0.02

print(f"Test MSE: {test_mse:.4f}")
print(f"Validation MSE: {validation_mse:.4f}")

# Comparing the test MSE to the validation MSE
if test_mse > validation_mse:
    print("The test MSE is higher than the validation MSE, indicating potential overfitting.")
else:
    print("The test MSE is comparable to or lower than the validation MSE, indicating good generalization.")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
# Test MSE: 0.0132
# Validation MSE: 0.0200
# The test MSE is comparable to or lower than the validation MSE, indicating good generalization.
